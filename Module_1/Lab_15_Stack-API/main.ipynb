# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
from stackapi import StackAPI
SITE = StackAPI('stackoverflow')
import requests
from datetime import datetime

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
questions = SITE.fetch('questions', min=datetime(2023, 3, 24), max=datetime(2023, 4, 24))
questions
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 294,
#  'total': 0,
#  'items': [{'tags': ['javascript', 'laravel', 'laravel-livewire'],
#    'owner': {'reputation': 3,
#     'user_id': 12408884,
#     'user_type': 'registered',
#     'profile_image': 'https://graph.facebook.com/10212027879292146/picture?type=large',
#     'display_name': 'Pasindu Hasanjaya Peiris',
#     'link': 'https://stackoverflow.com/users/12408884/pasindu-hasanjaya-peiris'},
#    'is_answered': False,
#    'view_count': 24,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1682294395,
#    'creation_date': 1682250479,
#    'question_id': 76084646,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/76084646/change-style-based-on-selected-value-with-dynamic-ids-laravel',
#    'title': 'Change style based on selected value with dynamic IDs Laravel'},
#   {'tags': ['tensorflow'],
#    'owner': {'reputation': 35,
# ...

# %%
answers = SITE.fetch('answers', min=datetime(2023, 3, 24), max=datetime(2023, 4, 24))
answers
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 290,
#  'total': 0,
#  'items': [{'owner': {'reputation': 3,
#     'user_id': 12408884,
#     'user_type': 'registered',
#     'profile_image': 'https://graph.facebook.com/10212027879292146/picture?type=large',
#     'display_name': 'Pasindu Hasanjaya Peiris',
#     'link': 'https://stackoverflow.com/users/12408884/pasindu-hasanjaya-peiris'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1682294395,
#    'creation_date': 1682294395,
#    'answer_id': 76087825,
#    'question_id': 76084646,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1,
#     'user_id': 21652788,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AGNmyxaUERSEg03bUfknPKyIR1XR7i-XimWjwHhN19AQ=k-s256',
#     'display_name': 'saeed latifi',
#     'link': 'https://stackoverflow.com/users/21652788/saeed-latifi'},
#    'is_accepted': False,
# ...

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
questions = SITE.fetch('questions', min=datetime(2023, 4, 24), max=datetime(2023, 4, 25), tagged = 'python')

top_q = []

for i in questions['items']:
    top_q.append(i['title'])

top_q[0]
# Out:
# 'Avoid plotting missing values on a line plot'

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
answers1 = SITE.fetch('answers', ids=[6784])
answers1
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 282,
#  'total': 0,
#  'items': [{'owner': {'reputation': 30649,
#     'user_id': 758,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://www.gravatar.com/avatar/0b4adc19284ed0751844d610555dc6b2?s=256&d=identicon&r=PG',
#     'display_name': 'Mark Renouf',
#     'link': 'https://stackoverflow.com/users/758/mark-renouf'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1218291583,
#    'creation_date': 1218291583,
#    'answer_id': 6784,
#    'question_id': 6778,
#    'content_license': 'CC BY-SA 2.5'}]}

# %%
answers2 = SITE.fetch('answers', ids=[6473])
answers2
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 281,
#  'total': 0,
#  'items': []}
