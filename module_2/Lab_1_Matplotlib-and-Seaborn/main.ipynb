# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
x = np.arange(0,100)
y = x*2
z = x**2

plt.plot(x,y, 'r', label='Bob')
plt.plot(x,z, 'g', label='John', lw=4, alpha = 0.5)
plt.title("Fig 1")
plt.legend()
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, sharey=False)

ax1.set_title("Fig1A")
ax1.plot(x,y, 'r', label='Bob')

ax2.set_title("Fig1B")
ax2.plot(x,z, 'g', label='John')


plt.tight_layout()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, sharey=False, figsize=(15,5))

ax1.set_title("Fig1B")
ax2.set_title("Fig1A")

ax1.plot(x,y, 'r', label='Bob')
ax2.plot(x,z, 'g', label='John')

ax1.legend(loc='upper left')
ax2.legend(loc='upper left')

ax1.set_ylabel('Numbers')
ax2.set_ylabel('More Numbers')


plt.legend()
plt.show()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
x = np.linspace(0, 4, 100)
y1 = lambda x: x**2
y2 = lambda x: np.exp(x)

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15,5))

ax1.set( title="Linear Scale", xscale='linear')
ax1.plot(x, y1(x), 'r', label='expo')

ax2.plot(x, y2(x), 'k')
ax2.set( title="Log Scale", yscale="log")

plt.show()

# %%
x = np.linspace(0, 4, 100)
y1 = lambda x: x**2
y2 = lambda x: np.exp(x)


fig, ax1 = plt.subplots()



ax1.set( title="Linear Scale", xlabel="Shared axis", xscale='linear', label="Linear")
ax1.plot(x, y1(x), 'r', label='linear')

ax2 = ax1.twinx()

ax2.plot(x, y2(x), 'k', label='log')
ax2.set(yscale="log")

plt.legend()
fig.tight_layout()
plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv('Fitbit2.csv')
fitbit.round()
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary
# 0  2015-05-08            1934    905      0.65       0              1.355  \
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active
# 0                      46                      0                    0  \
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month.
# Use the appropriate visualization to show the median steps by month.
# Is a Fitbitter more active on weekend or workdays?
# All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED

median_steps = fitbit["Steps"].groupby(fitbit["Months_encoded"]).median()

# %% [markdown]
# _____________________________________________________________________________________________________________________________________

# %%
ax1 = sns.barplot(data=fitbit, x="Months_encoded", y="Steps")

# %%
# MEDIAN STEPS BY MONTH_ENCODED
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12,4))

ax1 = sns.barplot(data=fitbit, x="Months", y="Steps", ax=ax1)

ax1.set_xticklabels( labels=["May", "June", "July", "August", "September", "October", "November", "December", "January", "February", "March", "April"], rotation=45)


# MEDIAN STEPS BY WORK_OR_WEEKEND

fitbit['Sum'] = fitbit['Minutes Lightly Active'] + fitbit['Minutes Fairly Active'] + fitbit['Minutes Very Active']

ax2 = sns.barplot(data=fitbit, x = "Work_or_Weekend" , y = "Calorie burned", ax=ax2)

plt.show()

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
plt.scatter(fitbit["Minutes Lightly Active"], y = fitbit["Steps"], alpha=0.75)

plt.scatter(fitbit["Minutes Fairly Active"], y = fitbit["Steps"], alpha=0.75)

plt.scatter(fitbit["Minutes Very Active"], y = fitbit["Steps"], alpha=0.75)

plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv('titanic.csv', sep=",")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1       0.0       3  \
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
titanic.select_dtypes(include= 'number' )
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
titanic.select_dtypes(exclude= 'number')
# Out:
#                                                    Name  Gender
# 0                               Braund, Mr. Owen Harris    male  \
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.style.use('classic')
titanic.plot(figsize = (12,6))
# Out:
# <Axes: >

# %%
sns.set_style('darkgrid')
titanic_plot = sns.scatterplot(data=titanic, x='Fare', y='Age')
plt.show()

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
plt.hist(titanic['Age'])
# Out:
# (array([ 72.,  78., 326., 347., 220., 136.,  75.,  42.,  10.,   3.]),
#  array([ 0.17 ,  8.153, 16.136, 24.119, 32.102, 40.085, 48.068, 56.051,
#         64.034, 72.017, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
fig, (ax1, ax2, ax3) = plt.subplots(nrows = 1, ncols=3, sharey=True, figsize=(15,5))


ax1.hist(titanic['Age'], bins=10)

ax2.hist(titanic['Age'], bins=20)

ax3.hist(titanic['Age'], bins=50)

plt.show()

# %%
# MEDIAN STEPS BY MONTH_ENCODED
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12,4))

ax1 = sns.barplot(data=fitbit, x="Months", y="Steps", ax=ax1)

ax1.set_xticklabels( labels=["May", "June", "July", "August", "September", "October", "November", "December", "January", "February", "March", "April"], rotation=45)


# MEDIAN STEPS BY WORK_OR_WEEKEND
fitbit['Sum'] = fitbit['Minutes Lightly Active'] + fitbit['Minutes Fairly Active'] + fitbit['Minutes Very Active']

ax2 = sns.barplot(data=fitbit, x = "Work_or_Weekend" , y = "Calorie burned", ax=ax2)

plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
It's adds precision to the data. Or makes bigger bins/categories to compare
"""
# Out:
# "\nIt's adds precision to the data. Or makes bigger bins/categories to compare\n"

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
ax1 = sns.boxplot( data = titanic, x="Age")

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
plt.hist( titanic['Gender'], bins=2 )
# Out:
# (array([843., 466.]),
#  array([0. , 0.5, 1. ]),
#  <BarContainer object of 2 artists>)

# %%
# Method 2 - seaborn
jeanpierre = sns.histplot( data = titanic, x="Gender")

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
titanic.value_counts("Pclass")
# Out:
# Pclass
# 3    709
# 1    323
# 2    277
# Name: count, dtype: int64

# %%
sns.histplot( data = titanic, x="Pclass", bins=3)
# Out:
# <Axes: xlabel='Pclass', ylabel='Count'>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
titanic["Age"].describe()
# Out:
# count    1309.000000
# mean       29.879186
# std        13.448335
# min         0.170000
# 25%        22.000000
# 50%        28.500000
# 75%        37.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
johnny = titanic["Age"].describe()

sns.boxplot( data = titanic, x= johnny , color="red");

# %%
sns.boxplot( data = titanic, x="Age", color="red");

# %%
plt.boxplot(data = titanic, x="Age" );

# %%
"""
For once the matplotlib is clearer 
"""
# Out:
# '\nFor once the matplotlib is clearer \n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
There are many outlying datapoints.
"""
# Out:
# '\nThere are many outlying datapoints.\n'

# %%
titanic["Age"].describe()
# Out:
# count    1309.000000
# mean       29.879186
# std        13.448335
# min         0.170000
# 25%        22.000000
# 50%        28.500000
# 75%        37.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1       0.0       3  \
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
sns.violinplot(data=titanic, x='Age' )
plt.show()

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib

a = titanic["Fare"]
b = titanic["Age"]

plt.scatter(data=titanic, a=titanic["Fare"], b=titanic["Age"]) 
# plt.scatter(b, 'b', label='Age') 

plt.title("Fare vs Age")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 6
#       3 a = titanic["Fare"]
#       4 b = titanic["Age"]
# ----> 6 plt.scatter(data=titanic, a=titanic["Fare"], b=titanic["Age"])
#       7 # plt.scatter(b, 'b', label='Age')
#       9 plt.title("Fare vs Age")
#
# TypeError: scatter() missing 2 required positional arguments: 'x' and 'y'

# %%
# Method 2 - seaborn

sns.scatterplot(data=titanic, x="Fare", y="Age", hue="Age", size=10, alpha=0.5) 

plt.title("Fare vs Age")
plt.legend()
plt.show()

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# Generate a large random dataset
rs = np.random.RandomState(33)
d = pd.DataFrame(data=rs.normal(size=(100, 26)),
                 columns=list(ascii_letters[26:]))

# Compute the correlation matrix
corr = d.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1       0.0       3  \
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %%
# titty = sns.load_dataset("titanic").pivot(index= "", columns = "Age", values = "Fare")
# tit = titanic[["Age","Fare"]]

tit = titanic.corr(numeric_only=True)

f, ax = plt.subplots(figsize=(20, 10))

sns.heatmap(data=tit, annot=True)
plt.show()

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
dude... we didn't see how to do that correlation thang.
SO i went with a heatmap, and this the best I could do... If yall can extract any useful insights, go ahead!
"""
# Out:
# "\ndude... we didn't see how to do that correlation thang.\n"

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
sns.barplot(data=titanic, x="Pclass", y="Age") 

plt.title("Fare vs Age")
plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.
#
# ***hint***: we never saw Facetgrid. How about we do labs that use the notions we see in the lesson. Or, see in the lessons what we will use in the labs.

# %%
sns.FacetGrid( data = titanic, row="Age", col="Gender" )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 sns.FacetGrid( data = titanic, row="Age", col="Gender" )
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:526, in FacetGrid.__init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws)
#     523 # --- Make the axes look good
#     525 self.set_titles()
# --> 526 self.tight_layout()
#     528 if despine:
#     529     self.despine()
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118, in Grid.tight_layout(self, *args, **kwargs)
#     116 if self._tight_layout_pad is not None:
#     117     kwargs.setdefault("pad", self._tight_layout_pad)
# ...
